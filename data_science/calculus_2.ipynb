# %% [markdown]
# ### Get and visualize derivative of sine function, f(x) = sin(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 100)
y = np.sin(x)
dy = np.cos(x)

print(f'derivative of sine function(-pi until pi): {dy}')

fig, ax = plt.subplots()
ax.plot(x, y, 'r', linewidth=2)
ax.plot(x, dy, 'g', linewidth=2)
ax.legend(['y = sin(x)', "dy/dx = cos(x)"])
plt.show()
# Out:
# derivative of sine function(-pi until pi): [-1.         -0.99798668 -0.99195481 -0.9819287  -0.9679487  -0.95007112
#  -0.92836793 -0.90292654 -0.87384938 -0.84125353 -0.80527026 -0.76604444
#  -0.72373404 -0.67850941 -0.63055267 -0.58005691 -0.52722547 -0.47227107
#  -0.41541501 -0.35688622 -0.29692038 -0.23575894 -0.17364818 -0.1108382
#  -0.04758192  0.01586596  0.07924996  0.14231484  0.20480667  0.26647381
#   0.32706796  0.38634513  0.44406661  0.5         0.55392006  0.60560969
#   0.65486073  0.70147489  0.74526445  0.78605309  0.82367658  0.85798341
#   0.88883545  0.91610846  0.93969262  0.95949297  0.97542979  0.98743889
#   0.99547192  0.99949654  0.99949654  0.99547192  0.98743889  0.97542979
#   0.95949297  0.93969262  0.91610846  0.88883545  0.85798341  0.82367658
#   0.78605309  0.74526445  0.70147489  0.65486073  0.60560969  0.55392006
#   0.5         0.44406661  0.38634513  0.32706796  0.26647381  0.20480667
# ...

# %% [markdown]
# ### Get integral sine function between pi/2 and pi

# %%
from sympy import *

x = Symbol('x')
f = sin(x)
integral = integrate(f, (x, np.pi/2, np.pi))
print(integral)

# Create an array of x values
x = np.linspace(np.pi/2, np.pi, 100)
y = np.sin(x)

# Plot the function
plt.plot(x, y, label='sin(x)', color='red')

# Fill the area under the curve
plt.fill_between(x, y, where=(x >= np.pi/2) & (x <= np.pi), color='magenta', alpha=0.5, label='Area under curve')

# Add title and labels
plt.title('Integral of sin(x) from π/2 to π')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.legend()

# Show the plot
plt.show()
# Out:
# 1.00000000000000

# %% [markdown]
# ### Get maximum of sine function between pi/2 and pi

# %%
def f(x):
    return np.sin(x)

def grad(x):
    return np.cos(x)

x = np.pi
learning_rate = 0.1
iterations = 100

for i in range(iterations):
    x = x + learning_rate*grad(x)

print(x)
print(f(x))
# Out:
# 1.5708515277730286
# 0.999999998476426
