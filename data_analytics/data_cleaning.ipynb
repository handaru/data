# %%
import pandas as pd

df = pd.read_csv('../datasets/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 12    13            4.8           3.0            1.4           0.1
# 26    27            5.0           3.4            1.6           0.4
# 25    26            5.0           3.0            1.6           0.2
# 44    45            5.1           3.8            1.9           0.4
# 38    39            4.4           3.0            1.3           0.2
# 96    97            5.7           2.9            4.2           1.3
# 145  146            6.7           3.0            5.2           2.3
# 116  117            6.5           3.0            5.5           1.8
# 8      9            4.4           2.9            1.4           0.2
# 73    74            6.1           2.8            4.7           1.2
#
#              Species
# 12       Iris-setosa
# 26       Iris-setosa
# 25       Iris-setosa
# 44       Iris-setosa
# 38       Iris-setosa
# 96   Iris-versicolor
# 145   Iris-virginica
# 116   Iris-virginica
# 8        Iris-setosa
# 73   Iris-versicolor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['SepalLengthCm'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 150 entries, 0 to 149
# Series name: SepalLengthCm
# Non-Null Count  Dtype
# --------------  -----
# 150 non-null    float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df2 = df.copy()

# %%
import numpy as np

df.loc[0, 'SepalLengthCm':'PetalWidthCm'] = np.nan
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  149 non-null    float64
#  2   SepalWidthCm   149 non-null    float64
#  3   PetalLengthCm  149 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df2.drop(columns=['Id'], inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  149 non-null    float64
#  1   SepalWidthCm   149 non-null    float64
#  2   PetalLengthCm  149 non-null    float64
#  3   PetalWidthCm   149 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            NaN           NaN            NaN           NaN  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Get the index of rows with missing values
missing_idx = df2.isnull().any(axis=1).index[df2.isnull().any(axis=1)]
print("Indices of rows with missing values:", missing_idx)
# Out:
# Indices of rows with missing values: Index([0], dtype='int64')

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            NaN           NaN            NaN           NaN  Iris-setosa

# %%
filter = df2['Species'] == 'Iris-setosa'
print(filter)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
df2.where(filter, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  49 non-null     float64
#  1   SepalWidthCm   49 non-null     float64
#  2   PetalLengthCm  49 non-null     float64
#  3   PetalWidthCm   49 non-null     float64
#  4   Species        50 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  149 non-null    float64
#  2   SepalWidthCm   149 non-null    float64
#  3   PetalLengthCm  149 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            NaN           NaN            NaN           NaN  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df[['SepalLengthCm']] = df[['SepalLengthCm']].fillna(value=df.groupby('Species')['SepalLengthCm'].mean().values[0])
df[['SepalWidthCm']] = df[['SepalWidthCm']].fillna(value=df.groupby('Species')['SepalWidthCm'].mean().values[0])
df[['PetalLengthCm']] = df[['PetalLengthCm']].fillna(value=df.groupby('Species')['PetalLengthCm'].mean().values[0])
df[['PetalWidthCm']] = df[['PetalWidthCm']].fillna(value=df.groupby('Species')['PetalWidthCm'].mean().values[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       5.004082      3.416327       1.465306      0.244898  Iris-setosa
# 1   2       4.900000      3.000000       1.400000      0.200000  Iris-setosa
# 2   3       4.700000      3.200000       1.300000      0.200000  Iris-setosa
# 3   4       4.600000      3.100000       1.500000      0.200000  Iris-setosa
# 4   5       5.000000      3.600000       1.400000      0.200000  Iris-setosa

# %%
print(df.groupby('Species')['SepalLengthCm'].mean().values[0])

# or

print(df[df['Species'] == 'Iris-setosa']['SepalLengthCm'].mean())

# or

print(df.query("Species == 'Iris-setosa'")['SepalLengthCm'].mean())
# Out:
# 5.004081632653062
# 5.004081632653062
# 5.004081632653062

# %%
df[['SepalLengthCm']] = df[['SepalLengthCm']].fillna(value=df2.groupby('Species')['SepalLengthCm'].mean().values[0])

# %%
df2.groupby('Species')['SepalLengthCm'].mean().values[0]
# Out:
# 5.004081632653061

# %%
df[df['Species'] == 'Iris-setosa']['SepalLengthCm'].mean()
# Out:
# 5.004081632653062

# %%
print(df[['Species']] == 'Iris-setosa')
# Out:
#      Species
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
#
# [150 rows x 1 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       5.004082      3.416327       1.465306      0.244898  Iris-setosa
# 1   2       4.900000      3.000000       1.400000      0.200000  Iris-setosa
# 2   3       4.700000      3.200000       1.300000      0.200000  Iris-setosa
# 3   4       4.600000      3.100000       1.500000      0.200000  Iris-setosa
# 4   5       5.000000      3.600000       1.400000      0.200000  Iris-setosa

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
np.max(df['PetalLengthCm'].values[0])
# Out:
# 1.4653061224489796

# %%
import pandas as pd

df_json = pd.read_json('../datasets/cloud_run_log.json')
df_json
# Out:
#           insertId                                        jsonPayload  \
# 0   MTIzNjQ5MjQ2Nw  {'detailedState': 'CONFIRMED', 'detailedCatego...
# 1   MjAxMzUxNjUyNw  {'description': 'We are experiencing an  issue...
# 2   MzU1MDk2NDk5Ng  {'symptom': 'Impacted customer requests will g...
# 3   MTUxODUzNTI2Ng  {'detailedState': 'CONFIRMED', 'updateTime': '...
# 4   MTAzNTcxNTUwNQ  {'state': 'CLOSED', 'impactedProductIds': '['9...
# 5   MTE3NTk2NzYxNA  {'relevance': 'PARTIALLY_RELATED', 'detailedCa...
# 6     ODIyNzAwMDMw  {'title': 'Cloud Monitoring users may experien...
# 7     Nzc5NzI3NjM2  {'workaround': 'None at this time.', 'symptom'...
# 8     14kjmce3b5hq                                                NaN
# 9     -ql5nzzdpf1c                                                NaN
# 10   -yw9ja5e3ibvg                                                NaN
# 11   -1dpm8xe7v8gw                                                NaN
# 12     1ob4xddkjxk                                                NaN
# 13   -vmcy91e2vsge                                                NaN
# 14   -6md34he3vvi6                                                NaN
# 15   -ql5nzze1k8xi                                                NaN
# 16    5lwvdle9ziuw                                                NaN
#
#                                              resource  \
# 0   {'type': 'servicehealth.googleapis.com/Event',...
# 1   {'type': 'servicehealth.googleapis.com/Event',...
# 2   {'type': 'servicehealth.googleapis.com/Event',...
# 3   {'type': 'servicehealth.googleapis.com/Event',...
# 4   {'type': 'servicehealth.googleapis.com/Event',...
# 5   {'type': 'servicehealth.googleapis.com/Event',...
# 6   {'type': 'servicehealth.googleapis.com/Event',...
# 7   {'type': 'servicehealth.googleapis.com/Event',...
# 8   {'type': 'project', 'labels': {'project_id': '...
# 9   {'type': 'project', 'labels': {'project_id': '...
# 10  {'type': 'project', 'labels': {'project_id': '...
# 11  {'type': 'project', 'labels': {'project_id': '...
# 12  {'type': 'project', 'labels': {'project_id': '...
# 13  {'type': 'project', 'labels': {'project_id': '...
# 14  {'type': 'project', 'labels': {'project_id': '...
# 15  {'type': 'project', 'labels': {'project_id': '...
# 16  {'type': 'project', 'labels': {'project_id': '...
#
#                           timestamp  \
# 0  2025-09-03 08:57:15.950779+00:00
# 1  2025-09-03 10:19:07.409427+00:00
# 2  2025-09-03 12:01:22.871072+00:00
# 3  2025-09-03 12:51:38.584692+00:00
# 4  2025-09-03 14:14:19.276306+00:00
# 5  2025-09-05 08:24:51.675912+00:00
# 6  2025-09-05 08:46:40.760997+00:00
# 7  2025-09-05 10:17:03.524701+00:00
# 8  2025-09-05 12:13:49.480093+00:00
# 9  2025-09-06 08:33:22.363606+00:00
# 10 2025-09-06 11:14:57.674278+00:00
# 11 2025-09-07 00:43:38.408466+00:00
# 12 2025-09-07 00:44:28.614811+00:00
# 13 2025-09-08 15:59:08.892615+00:00
# 14 2025-09-08 17:59:36.154368+00:00
# 15 2025-09-09 02:46:59.023498+00:00
# 16 2025-09-09 05:58:24.318174+00:00
#
#                                                labels  \
# 0   {'servicehealth.googleapis.com/updated_fields'...
# 1   {'servicehealth.googleapis.com/updated_fields'...
# 2   {'servicehealth.googleapis.com/new_event': 'fa...
# 3   {'servicehealth.googleapis.com/new_event': 'fa...
# 4   {'servicehealth.googleapis.com/new_event': 'fa...
# 5   {'servicehealth.googleapis.com/new_event': 'tr...
# 6   {'servicehealth.googleapis.com/updated_fields'...
# 7   {'servicehealth.googleapis.com/new_event': 'fa...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#                                               logName  \
# 0   projects/figsarai-2fe08/logs/servicehealth.goo...
# 1   projects/figsarai-2fe08/logs/servicehealth.goo...
# 2   projects/figsarai-2fe08/logs/servicehealth.goo...
# 3   projects/figsarai-2fe08/logs/servicehealth.goo...
# 4   projects/figsarai-2fe08/logs/servicehealth.goo...
# 5   projects/figsarai-2fe08/logs/servicehealth.goo...
# 6   projects/figsarai-2fe08/logs/servicehealth.goo...
# 7   projects/figsarai-2fe08/logs/servicehealth.goo...
# 8   projects/figsarai-2fe08/logs/cloudaudit.google...
# 9   projects/figsarai-2fe08/logs/cloudaudit.google...
# 10  projects/figsarai-2fe08/logs/cloudaudit.google...
# 11  projects/figsarai-2fe08/logs/cloudaudit.google...
# 12  projects/figsarai-2fe08/logs/cloudaudit.google...
# 13  projects/figsarai-2fe08/logs/cloudaudit.google...
# 14  projects/figsarai-2fe08/logs/cloudaudit.google...
# 15  projects/figsarai-2fe08/logs/cloudaudit.google...
# 16  projects/figsarai-2fe08/logs/cloudaudit.google...
#
#                   receiveTimestamp  \
# 0   2025-09-03T08:57:27.860582655Z
# 1   2025-09-03T10:19:14.751857856Z
# 2   2025-09-03T12:01:32.948606583Z
# 3   2025-09-03T12:51:49.971038596Z
# 4   2025-09-03T14:14:28.715743316Z
# 5   2025-09-05T08:25:17.036987087Z
# 6   2025-09-05T08:46:54.883854693Z
# 7   2025-09-05T10:17:16.901710396Z
# 8   2025-09-05T12:13:50.489145620Z
# 9   2025-09-06T08:33:22.929288110Z
# 10  2025-09-06T11:14:57.771336824Z
# 11  2025-09-07T00:43:38.954636398Z
# 12  2025-09-07T00:44:29.295206119Z
# 13  2025-09-08T15:59:09.686671518Z
# 14  2025-09-08T17:59:36.784604038Z
# 15  2025-09-09T02:46:59.947809343Z
# 16  2025-09-09T05:58:24.805558994Z
#
#                                          protoPayload severity
# 0                                                 NaN      NaN
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 9   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 10  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 11  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 12  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 13  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 14  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 15  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 16  {'@type': 'type.googleapis.com/google.cloud.au...     INFO

# %%
df_json.isnull().sum()
# Out:
# insertId            0
# jsonPayload         9
# resource            0
# timestamp           0
# labels              9
# logName             0
# receiveTimestamp    0
# protoPayload        8
# severity            8
# dtype: int64

# %%
import pandas as pd

# Check for missing values in df_json
print(df_json.isnull().sum())
# Out:
# insertId            0
# jsonPayload         9
# resource            0
# timestamp           0
# labels              9
# logName             0
# receiveTimestamp    0
# protoPayload        8
# severity            8
# dtype: int64

# %%
for i in range(len(df_json.columns) -1):
    df_json[df_json.columns[i]] = df_json[df_json.columns[i]].map(lambda x: {} if pd.isna(x) else x)
df_json
# Out:
#           insertId                                        jsonPayload  \
# 0   MTIzNjQ5MjQ2Nw  {'detailedState': 'CONFIRMED', 'detailedCatego...
# 1   MjAxMzUxNjUyNw  {'description': 'We are experiencing an  issue...
# 2   MzU1MDk2NDk5Ng  {'symptom': 'Impacted customer requests will g...
# 3   MTUxODUzNTI2Ng  {'detailedState': 'CONFIRMED', 'updateTime': '...
# 4   MTAzNTcxNTUwNQ  {'state': 'CLOSED', 'impactedProductIds': '['9...
# 5   MTE3NTk2NzYxNA  {'relevance': 'PARTIALLY_RELATED', 'detailedCa...
# 6     ODIyNzAwMDMw  {'title': 'Cloud Monitoring users may experien...
# 7     Nzc5NzI3NjM2  {'workaround': 'None at this time.', 'symptom'...
# 8     14kjmce3b5hq                                                 {}
# 9     -ql5nzzdpf1c                                                 {}
# 10   -yw9ja5e3ibvg                                                 {}
# 11   -1dpm8xe7v8gw                                                 {}
# 12     1ob4xddkjxk                                                 {}
# 13   -vmcy91e2vsge                                                 {}
# 14   -6md34he3vvi6                                                 {}
# 15   -ql5nzze1k8xi                                                 {}
# 16    5lwvdle9ziuw                                                 {}
#
#                                              resource  \
# 0   {'type': 'servicehealth.googleapis.com/Event',...
# 1   {'type': 'servicehealth.googleapis.com/Event',...
# 2   {'type': 'servicehealth.googleapis.com/Event',...
# 3   {'type': 'servicehealth.googleapis.com/Event',...
# 4   {'type': 'servicehealth.googleapis.com/Event',...
# 5   {'type': 'servicehealth.googleapis.com/Event',...
# 6   {'type': 'servicehealth.googleapis.com/Event',...
# 7   {'type': 'servicehealth.googleapis.com/Event',...
# 8   {'type': 'project', 'labels': {'project_id': '...
# 9   {'type': 'project', 'labels': {'project_id': '...
# 10  {'type': 'project', 'labels': {'project_id': '...
# 11  {'type': 'project', 'labels': {'project_id': '...
# 12  {'type': 'project', 'labels': {'project_id': '...
# 13  {'type': 'project', 'labels': {'project_id': '...
# 14  {'type': 'project', 'labels': {'project_id': '...
# 15  {'type': 'project', 'labels': {'project_id': '...
# 16  {'type': 'project', 'labels': {'project_id': '...
#
#                           timestamp  \
# 0  2025-09-03 08:57:15.950779+00:00
# 1  2025-09-03 10:19:07.409427+00:00
# 2  2025-09-03 12:01:22.871072+00:00
# 3  2025-09-03 12:51:38.584692+00:00
# 4  2025-09-03 14:14:19.276306+00:00
# 5  2025-09-05 08:24:51.675912+00:00
# 6  2025-09-05 08:46:40.760997+00:00
# 7  2025-09-05 10:17:03.524701+00:00
# 8  2025-09-05 12:13:49.480093+00:00
# 9  2025-09-06 08:33:22.363606+00:00
# 10 2025-09-06 11:14:57.674278+00:00
# 11 2025-09-07 00:43:38.408466+00:00
# 12 2025-09-07 00:44:28.614811+00:00
# 13 2025-09-08 15:59:08.892615+00:00
# 14 2025-09-08 17:59:36.154368+00:00
# 15 2025-09-09 02:46:59.023498+00:00
# 16 2025-09-09 05:58:24.318174+00:00
#
#                                                labels  \
# 0   {'servicehealth.googleapis.com/updated_fields'...
# 1   {'servicehealth.googleapis.com/updated_fields'...
# 2   {'servicehealth.googleapis.com/new_event': 'fa...
# 3   {'servicehealth.googleapis.com/new_event': 'fa...
# 4   {'servicehealth.googleapis.com/new_event': 'fa...
# 5   {'servicehealth.googleapis.com/new_event': 'tr...
# 6   {'servicehealth.googleapis.com/updated_fields'...
# 7   {'servicehealth.googleapis.com/new_event': 'fa...
# 8                                                  {}
# 9                                                  {}
# 10                                                 {}
# 11                                                 {}
# 12                                                 {}
# 13                                                 {}
# 14                                                 {}
# 15                                                 {}
# 16                                                 {}
#
#                                               logName  \
# 0   projects/figsarai-2fe08/logs/servicehealth.goo...
# 1   projects/figsarai-2fe08/logs/servicehealth.goo...
# 2   projects/figsarai-2fe08/logs/servicehealth.goo...
# 3   projects/figsarai-2fe08/logs/servicehealth.goo...
# 4   projects/figsarai-2fe08/logs/servicehealth.goo...
# 5   projects/figsarai-2fe08/logs/servicehealth.goo...
# 6   projects/figsarai-2fe08/logs/servicehealth.goo...
# 7   projects/figsarai-2fe08/logs/servicehealth.goo...
# 8   projects/figsarai-2fe08/logs/cloudaudit.google...
# 9   projects/figsarai-2fe08/logs/cloudaudit.google...
# 10  projects/figsarai-2fe08/logs/cloudaudit.google...
# 11  projects/figsarai-2fe08/logs/cloudaudit.google...
# 12  projects/figsarai-2fe08/logs/cloudaudit.google...
# 13  projects/figsarai-2fe08/logs/cloudaudit.google...
# 14  projects/figsarai-2fe08/logs/cloudaudit.google...
# 15  projects/figsarai-2fe08/logs/cloudaudit.google...
# 16  projects/figsarai-2fe08/logs/cloudaudit.google...
#
#                   receiveTimestamp  \
# 0   2025-09-03T08:57:27.860582655Z
# 1   2025-09-03T10:19:14.751857856Z
# 2   2025-09-03T12:01:32.948606583Z
# 3   2025-09-03T12:51:49.971038596Z
# 4   2025-09-03T14:14:28.715743316Z
# 5   2025-09-05T08:25:17.036987087Z
# 6   2025-09-05T08:46:54.883854693Z
# 7   2025-09-05T10:17:16.901710396Z
# 8   2025-09-05T12:13:50.489145620Z
# 9   2025-09-06T08:33:22.929288110Z
# 10  2025-09-06T11:14:57.771336824Z
# 11  2025-09-07T00:43:38.954636398Z
# 12  2025-09-07T00:44:29.295206119Z
# 13  2025-09-08T15:59:09.686671518Z
# 14  2025-09-08T17:59:36.784604038Z
# 15  2025-09-09T02:46:59.947809343Z
# 16  2025-09-09T05:58:24.805558994Z
#
#                                          protoPayload severity
# 0                                                  {}      NaN
# 1                                                  {}      NaN
# 2                                                  {}      NaN
# 3                                                  {}      NaN
# 4                                                  {}      NaN
# 5                                                  {}      NaN
# 6                                                  {}      NaN
# 7                                                  {}      NaN
# 8   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 9   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 10  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 11  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 12  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 13  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 14  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 15  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 16  {'@type': 'type.googleapis.com/google.cloud.au...     INFO

# %%
df_json[df_json.columns[len(df_json.columns)-1]] = df_json[df_json.columns[len(df_json.columns)-1]].map(lambda x: 'UNKNOWN' if pd.isna(x) else x)
df_json
# Out:
#           insertId                                        jsonPayload  \
# 0   MTIzNjQ5MjQ2Nw  {'detailedState': 'CONFIRMED', 'detailedCatego...
# 1   MjAxMzUxNjUyNw  {'description': 'We are experiencing an  issue...
# 2   MzU1MDk2NDk5Ng  {'symptom': 'Impacted customer requests will g...
# 3   MTUxODUzNTI2Ng  {'detailedState': 'CONFIRMED', 'updateTime': '...
# 4   MTAzNTcxNTUwNQ  {'state': 'CLOSED', 'impactedProductIds': '['9...
# 5   MTE3NTk2NzYxNA  {'relevance': 'PARTIALLY_RELATED', 'detailedCa...
# 6     ODIyNzAwMDMw  {'title': 'Cloud Monitoring users may experien...
# 7     Nzc5NzI3NjM2  {'workaround': 'None at this time.', 'symptom'...
# 8     14kjmce3b5hq                                                 {}
# 9     -ql5nzzdpf1c                                                 {}
# 10   -yw9ja5e3ibvg                                                 {}
# 11   -1dpm8xe7v8gw                                                 {}
# 12     1ob4xddkjxk                                                 {}
# 13   -vmcy91e2vsge                                                 {}
# 14   -6md34he3vvi6                                                 {}
# 15   -ql5nzze1k8xi                                                 {}
# 16    5lwvdle9ziuw                                                 {}
#
#                                              resource  \
# 0   {'type': 'servicehealth.googleapis.com/Event',...
# 1   {'type': 'servicehealth.googleapis.com/Event',...
# 2   {'type': 'servicehealth.googleapis.com/Event',...
# 3   {'type': 'servicehealth.googleapis.com/Event',...
# 4   {'type': 'servicehealth.googleapis.com/Event',...
# 5   {'type': 'servicehealth.googleapis.com/Event',...
# 6   {'type': 'servicehealth.googleapis.com/Event',...
# 7   {'type': 'servicehealth.googleapis.com/Event',...
# 8   {'type': 'project', 'labels': {'project_id': '...
# 9   {'type': 'project', 'labels': {'project_id': '...
# 10  {'type': 'project', 'labels': {'project_id': '...
# 11  {'type': 'project', 'labels': {'project_id': '...
# 12  {'type': 'project', 'labels': {'project_id': '...
# 13  {'type': 'project', 'labels': {'project_id': '...
# 14  {'type': 'project', 'labels': {'project_id': '...
# 15  {'type': 'project', 'labels': {'project_id': '...
# 16  {'type': 'project', 'labels': {'project_id': '...
#
#                           timestamp  \
# 0  2025-09-03 08:57:15.950779+00:00
# 1  2025-09-03 10:19:07.409427+00:00
# 2  2025-09-03 12:01:22.871072+00:00
# 3  2025-09-03 12:51:38.584692+00:00
# 4  2025-09-03 14:14:19.276306+00:00
# 5  2025-09-05 08:24:51.675912+00:00
# 6  2025-09-05 08:46:40.760997+00:00
# 7  2025-09-05 10:17:03.524701+00:00
# 8  2025-09-05 12:13:49.480093+00:00
# 9  2025-09-06 08:33:22.363606+00:00
# 10 2025-09-06 11:14:57.674278+00:00
# 11 2025-09-07 00:43:38.408466+00:00
# 12 2025-09-07 00:44:28.614811+00:00
# 13 2025-09-08 15:59:08.892615+00:00
# 14 2025-09-08 17:59:36.154368+00:00
# 15 2025-09-09 02:46:59.023498+00:00
# 16 2025-09-09 05:58:24.318174+00:00
#
#                                                labels  \
# 0   {'servicehealth.googleapis.com/updated_fields'...
# 1   {'servicehealth.googleapis.com/updated_fields'...
# 2   {'servicehealth.googleapis.com/new_event': 'fa...
# 3   {'servicehealth.googleapis.com/new_event': 'fa...
# 4   {'servicehealth.googleapis.com/new_event': 'fa...
# 5   {'servicehealth.googleapis.com/new_event': 'tr...
# 6   {'servicehealth.googleapis.com/updated_fields'...
# 7   {'servicehealth.googleapis.com/new_event': 'fa...
# 8                                                  {}
# 9                                                  {}
# 10                                                 {}
# 11                                                 {}
# 12                                                 {}
# 13                                                 {}
# 14                                                 {}
# 15                                                 {}
# 16                                                 {}
#
#                                               logName  \
# 0   projects/figsarai-2fe08/logs/servicehealth.goo...
# 1   projects/figsarai-2fe08/logs/servicehealth.goo...
# 2   projects/figsarai-2fe08/logs/servicehealth.goo...
# 3   projects/figsarai-2fe08/logs/servicehealth.goo...
# 4   projects/figsarai-2fe08/logs/servicehealth.goo...
# 5   projects/figsarai-2fe08/logs/servicehealth.goo...
# 6   projects/figsarai-2fe08/logs/servicehealth.goo...
# 7   projects/figsarai-2fe08/logs/servicehealth.goo...
# 8   projects/figsarai-2fe08/logs/cloudaudit.google...
# 9   projects/figsarai-2fe08/logs/cloudaudit.google...
# 10  projects/figsarai-2fe08/logs/cloudaudit.google...
# 11  projects/figsarai-2fe08/logs/cloudaudit.google...
# 12  projects/figsarai-2fe08/logs/cloudaudit.google...
# 13  projects/figsarai-2fe08/logs/cloudaudit.google...
# 14  projects/figsarai-2fe08/logs/cloudaudit.google...
# 15  projects/figsarai-2fe08/logs/cloudaudit.google...
# 16  projects/figsarai-2fe08/logs/cloudaudit.google...
#
#                   receiveTimestamp  \
# 0   2025-09-03T08:57:27.860582655Z
# 1   2025-09-03T10:19:14.751857856Z
# 2   2025-09-03T12:01:32.948606583Z
# 3   2025-09-03T12:51:49.971038596Z
# 4   2025-09-03T14:14:28.715743316Z
# 5   2025-09-05T08:25:17.036987087Z
# 6   2025-09-05T08:46:54.883854693Z
# 7   2025-09-05T10:17:16.901710396Z
# 8   2025-09-05T12:13:50.489145620Z
# 9   2025-09-06T08:33:22.929288110Z
# 10  2025-09-06T11:14:57.771336824Z
# 11  2025-09-07T00:43:38.954636398Z
# 12  2025-09-07T00:44:29.295206119Z
# 13  2025-09-08T15:59:09.686671518Z
# 14  2025-09-08T17:59:36.784604038Z
# 15  2025-09-09T02:46:59.947809343Z
# 16  2025-09-09T05:58:24.805558994Z
#
#                                          protoPayload severity
# 0                                                  {}  UNKNOWN
# 1                                                  {}  UNKNOWN
# 2                                                  {}  UNKNOWN
# 3                                                  {}  UNKNOWN
# 4                                                  {}  UNKNOWN
# 5                                                  {}  UNKNOWN
# 6                                                  {}  UNKNOWN
# 7                                                  {}  UNKNOWN
# 8   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 9   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 10  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 11  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 12  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 13  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 14  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 15  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 16  {'@type': 'type.googleapis.com/google.cloud.au...     INFO

# %%
# Out:
#           insertId                                        jsonPayload  \
# 0   MTIzNjQ5MjQ2Nw  {'detailedState': 'CONFIRMED', 'detailedCatego...
# 1   MjAxMzUxNjUyNw  {'description': 'We are experiencing an  issue...
# 2   MzU1MDk2NDk5Ng  {'symptom': 'Impacted customer requests will g...
# 3   MTUxODUzNTI2Ng  {'detailedState': 'CONFIRMED', 'updateTime': '...
# 4   MTAzNTcxNTUwNQ  {'state': 'CLOSED', 'impactedProductIds': '['9...
# 5   MTE3NTk2NzYxNA  {'relevance': 'PARTIALLY_RELATED', 'detailedCa...
# 6     ODIyNzAwMDMw  {'title': 'Cloud Monitoring users may experien...
# 7     Nzc5NzI3NjM2  {'workaround': 'None at this time.', 'symptom'...
# 8     14kjmce3b5hq                                                 {}
# 9     -ql5nzzdpf1c                                                 {}
# 10   -yw9ja5e3ibvg                                                 {}
# 11   -1dpm8xe7v8gw                                                 {}
# 12     1ob4xddkjxk                                                 {}
# 13   -vmcy91e2vsge                                                 {}
# 14   -6md34he3vvi6                                                 {}
# 15   -ql5nzze1k8xi                                                 {}
# 16    5lwvdle9ziuw                                                 {}
#
#                                              resource  \
# 0   {'type': 'servicehealth.googleapis.com/Event',...
# 1   {'type': 'servicehealth.googleapis.com/Event',...
# 2   {'type': 'servicehealth.googleapis.com/Event',...
# 3   {'type': 'servicehealth.googleapis.com/Event',...
# 4   {'type': 'servicehealth.googleapis.com/Event',...
# 5   {'type': 'servicehealth.googleapis.com/Event',...
# 6   {'type': 'servicehealth.googleapis.com/Event',...
# 7   {'type': 'servicehealth.googleapis.com/Event',...
# 8   {'type': 'project', 'labels': {'project_id': '...
# 9   {'type': 'project', 'labels': {'project_id': '...
# 10  {'type': 'project', 'labels': {'project_id': '...
# 11  {'type': 'project', 'labels': {'project_id': '...
# 12  {'type': 'project', 'labels': {'project_id': '...
# 13  {'type': 'project', 'labels': {'project_id': '...
# 14  {'type': 'project', 'labels': {'project_id': '...
# 15  {'type': 'project', 'labels': {'project_id': '...
# 16  {'type': 'project', 'labels': {'project_id': '...
#
#                           timestamp  \
# 0  2025-09-03 08:57:15.950779+00:00
# 1  2025-09-03 10:19:07.409427+00:00
# 2  2025-09-03 12:01:22.871072+00:00
# 3  2025-09-03 12:51:38.584692+00:00
# 4  2025-09-03 14:14:19.276306+00:00
# 5  2025-09-05 08:24:51.675912+00:00
# 6  2025-09-05 08:46:40.760997+00:00
# 7  2025-09-05 10:17:03.524701+00:00
# 8  2025-09-05 12:13:49.480093+00:00
# 9  2025-09-06 08:33:22.363606+00:00
# 10 2025-09-06 11:14:57.674278+00:00
# 11 2025-09-07 00:43:38.408466+00:00
# 12 2025-09-07 00:44:28.614811+00:00
# 13 2025-09-08 15:59:08.892615+00:00
# 14 2025-09-08 17:59:36.154368+00:00
# 15 2025-09-09 02:46:59.023498+00:00
# 16 2025-09-09 05:58:24.318174+00:00
#
#                                                labels  \
# 0   {'servicehealth.googleapis.com/updated_fields'...
# 1   {'servicehealth.googleapis.com/updated_fields'...
# 2   {'servicehealth.googleapis.com/new_event': 'fa...
# 3   {'servicehealth.googleapis.com/new_event': 'fa...
# 4   {'servicehealth.googleapis.com/new_event': 'fa...
# 5   {'servicehealth.googleapis.com/new_event': 'tr...
# 6   {'servicehealth.googleapis.com/updated_fields'...
# 7   {'servicehealth.googleapis.com/new_event': 'fa...
# 8                                                  {}
# 9                                                  {}
# 10                                                 {}
# 11                                                 {}
# 12                                                 {}
# 13                                                 {}
# 14                                                 {}
# 15                                                 {}
# 16                                                 {}
#
#                                               logName  \
# 0   projects/figsarai-2fe08/logs/servicehealth.goo...
# 1   projects/figsarai-2fe08/logs/servicehealth.goo...
# 2   projects/figsarai-2fe08/logs/servicehealth.goo...
# 3   projects/figsarai-2fe08/logs/servicehealth.goo...
# 4   projects/figsarai-2fe08/logs/servicehealth.goo...
# 5   projects/figsarai-2fe08/logs/servicehealth.goo...
# 6   projects/figsarai-2fe08/logs/servicehealth.goo...
# 7   projects/figsarai-2fe08/logs/servicehealth.goo...
# 8   projects/figsarai-2fe08/logs/cloudaudit.google...
# 9   projects/figsarai-2fe08/logs/cloudaudit.google...
# 10  projects/figsarai-2fe08/logs/cloudaudit.google...
# 11  projects/figsarai-2fe08/logs/cloudaudit.google...
# 12  projects/figsarai-2fe08/logs/cloudaudit.google...
# 13  projects/figsarai-2fe08/logs/cloudaudit.google...
# 14  projects/figsarai-2fe08/logs/cloudaudit.google...
# 15  projects/figsarai-2fe08/logs/cloudaudit.google...
# 16  projects/figsarai-2fe08/logs/cloudaudit.google...
#
#                   receiveTimestamp  \
# 0   2025-09-03T08:57:27.860582655Z
# 1   2025-09-03T10:19:14.751857856Z
# 2   2025-09-03T12:01:32.948606583Z
# 3   2025-09-03T12:51:49.971038596Z
# 4   2025-09-03T14:14:28.715743316Z
# 5   2025-09-05T08:25:17.036987087Z
# 6   2025-09-05T08:46:54.883854693Z
# 7   2025-09-05T10:17:16.901710396Z
# 8   2025-09-05T12:13:50.489145620Z
# 9   2025-09-06T08:33:22.929288110Z
# 10  2025-09-06T11:14:57.771336824Z
# 11  2025-09-07T00:43:38.954636398Z
# 12  2025-09-07T00:44:29.295206119Z
# 13  2025-09-08T15:59:09.686671518Z
# 14  2025-09-08T17:59:36.784604038Z
# 15  2025-09-09T02:46:59.947809343Z
# 16  2025-09-09T05:58:24.805558994Z
#
#                                          protoPayload severity
# 0                                                  {}  UNKNOWN
# 1                                                  {}  UNKNOWN
# 2                                                  {}  UNKNOWN
# 3                                                  {}  UNKNOWN
# 4                                                  {}  UNKNOWN
# 5                                                  {}  UNKNOWN
# 6                                                  {}  UNKNOWN
# 7                                                  {}  UNKNOWN
# 8   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 9   {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 10  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 11  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 12  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 13  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 14  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 15  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
# 16  {'@type': 'type.googleapis.com/google.cloud.au...     INFO
